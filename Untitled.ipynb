# %%
# !git pull
# Out:
# Updating f95f696..2a71b83
# From https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-
#    f95f696..2a71b83  main       -> origin/main
# Fast-forward
#  .../Heart_Diesease_Prediction-checkpoint.ipynb     |   41 -
#  .../git commands-checkpoint.ipynb                  |   38 +-
#  .../Heart_Diesease_Prediction-checkpoint.ipynb     | 1275 ++++++++++++++++++++
#  .../git commands-checkpoint.ipynb                  |  393 ++++++
#  Data/Heart_Diesease_Prediction.ipynb               | 1275 ++++++++++++++++++++
#  Data/git commands.ipynb                            |  564 +++++++++
#  git commands.ipynb                                 |  337 ++++++
#  7 files changed, 3867 insertions(+), 56 deletions(-)
#  delete mode 100644 .ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb
#  rename Heart_Diesease_Prediction.ipynb => .ipynb_checkpoints/git commands-checkpoint.ipynb (50%)
#  create mode 100644 Data/.ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb
# ...
