# %%
# !git clone https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-.git
# Out:
# Cloning into 'Heart_Disease_Prediction-PRCP-1016-'...

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-
#  * branch            main       -> FETCH_HEAD

# %%
# !git add .
# Out:
# warning: in the working copy of 'Heart_Diesease_Prediction.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of '.ipynb_checkpoints/git commands-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'git commands.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "update"
# Out:
# [main 3c964d3] update
#  3 files changed, 189 insertions(+), 17 deletions(-)
#  create mode 100644 .ipynb_checkpoints/git commands-checkpoint.ipynb
#  create mode 100644 git commands.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-.git
#    f95f696..3c964d3  main -> main

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-
#  * branch            main       -> FETCH_HEAD

# %%
# !git add .
# Out:
# warning: in the working copy of 'git commands.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Data/.ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Data/Heart_Diesease_Prediction.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "update"
# Out:
# [main b692be7] update
#  5 files changed, 1405 insertions(+), 139 deletions(-)
#  delete mode 100644 .ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb
#  create mode 100644 Data/.ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb
#  create mode 100644 Data/Heart_Diesease_Prediction.ipynb
#  delete mode 100644 Heart_Diesease_Prediction.ipynb

# %%
# !git push origin main
# Out:
# To https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-.git
#    3c964d3..b692be7  main -> main

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-
#  * branch            main       -> FETCH_HEAD

# %%
# !git add .
# Out:
# warning: in the working copy of 'Data/.ipynb_checkpoints/Heart_Diesease_Prediction-checkpoint.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'Data/Heart_Diesease_Prediction.ipynb', LF will be replaced by CRLF the next time Git touches it
# warning: in the working copy of 'git commands.ipynb', LF will be replaced by CRLF the next time Git touches it

# %%
# !git commit -m "update"
# Out:
# [main 4f3fea7] update
#  3 files changed, 471 insertions(+), 5 deletions(-)

# %%
# !git push origin main
# Out:
# To https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-.git
#    b692be7..4f3fea7  main -> main

# %%
# !git pull origin main
# Out:
# Already up to date.
# From https://github.com/Arpithanj/Heart_Disease_Prediction-PRCP-1016-
#  * branch            main       -> FETCH_HEAD

# %%
# !git add .
